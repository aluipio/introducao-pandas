# %% [markdown]
# # Data Science - Introdução a Biblioteca Pandas
#
# ![Pandas](https://raw.githubusercontent.com/aluipio/introducao-pandas/main/pandas-python-interface.png.webp)

# %% [markdown]
# ___
# # 1 - Introdução ao Pandas

# %% [markdown]
# Biblioteca em linguagem python comumente utilizada para Analise de Dados e Ciências de Dados. Idealizada para auxiliar no processo de tratamento e análise de dados com uso da linguagem Python. Sendo uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy.

# %% [markdown]
# ## 1.1 - Introdução Python

# %% [markdown]
# Python é uma linguagem de programação de alto nível com suporte a múltiplos paradigmas de programação. É um projeto open source e desde seu surgimento, em 1991, vem se tornando uma das linguagens de programação interpretadas mais populares.
#
# Nos últimos anos Python desenvolveu uma comunidade ativa de processamento científico e análise de dados e vem se destacando como uma das linguagens mais relevantes quando o assundo é ciência de dados e machine learning, tanto no ambiente acadêmico como também no mercado

# %% [markdown]
# ## 1.2 - Instalação e Ambientes de desenvolvimento

# %% [markdown]
# Ambiente Local - Instalação:
# - Python: https://www.python.org/downloads/
# - Anaconda: https://www.anaconda.com/distribution/
#
# Ambiente On-Line:
# - Google COLAB: https://colab.research.google.com/

# %% [markdown]
# ## 1.3 - Carregando

# %%
# Importando a biblioteca Pandas - 
import pandas as pd

# %% [markdown]
# ### Estruturas de dados
#
# #### Series
#
# Series são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado. Os rótulos das linhas são chamados de index. A forma básica de criação de uma Series é a seguinte:
#
#     s = pd.Series(dados, index = index)
# O argumento dados pode ser um dicionário, uma lista, um array Numpy ou uma constante.
#
# #### DataFrame
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linha e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
#     df = pd.DataFrame(dados, index = index, columns = columns)
# O argumento dados pode ser um dicionário, uma lista, um array Numpy, uma Series e outro DataFrame.
#
# Documentação: https://pandas.pydata.org/pandas-docs/version/0.25/

# %%
# Carregando dataset - param sep identifica o separador
dataset = "https://raw.githubusercontent.com/aluipio/introducao-pandas/main/dataset-aluguel.csv"
df = pd.read_csv(dataset , sep = ";")
df.head(1)
# Out:
#         Tipo      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0  Quitinete  Copacabana        1      0       0    40  1700.0       500.0
#
#    IPTU
# 0  60.0

# %%
# Carregamento de dataset - index_col = 0 -> remove a contagem das colunas 
df2 = pd.read_csv(dataset , sep = ";" ,index_col = 0)
df2.head(1)
# Out:
#                Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  IPTU
# Tipo
# Quitinete  Copacabana        1      0       0    40  1700.0       500.0  60.0

# %% [markdown]
# ___
# # 2 - Conhecendo os dados

# %% [markdown]
# ## 2.1 - Visualização de Dados

# %%
# Retorna o tipo da variável df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Conhecendo as variáveis e os tipos de dados
df.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
# Detalha as variáveis do DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Detalha as variáveis estatísticas do tipo inteiras
df.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# max    6.552570e+06  2.705307e+07

# %%
# Param include="all" -> retorna descrição de todas as variáveis
df.describe(include="all")
# Out:
#                Tipo           Bairro       Quartos         Vagas  \
# count         32960            32960  32960.000000  32960.000000
# unique           22              162           NaN           NaN
# top     Apartamento  Barra da Tijuca           NaN           NaN
# freq          19532             6259           NaN           NaN
# mean            NaN              NaN      1.771390      1.749059
# std             NaN              NaN      1.717869     20.380402
# min             NaN              NaN      0.000000      0.000000
# 25%             NaN              NaN      0.000000      0.000000
# 50%             NaN              NaN      2.000000      1.000000
# 75%             NaN              NaN      3.000000      2.000000
# max             NaN              NaN    100.000000   1966.000000
#
#               Suites          Area         Valor    Condominio          IPTU
# count   32960.000000  32960.000000  3.294300e+04  2.886700e+04  2.272300e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.665777    231.901547  1.295266e+04  2.388062e+03  2.364410e+03
# std         1.176525   1135.254152  6.675220e+05  3.918496e+04  1.795641e+05
# min         0.000000      0.000000  7.500000e+01  1.000000e+00  1.000000e+00
# 25%         0.000000     55.000000  1.500000e+03  5.900000e+02  1.100000e+02
# 50%         0.000000     87.000000  2.800000e+03  9.900000e+02  2.500000e+02
# 75%         1.000000    170.000000  6.500000e+03  1.800000e+03  6.970000e+02
# max        70.000000  90000.000000  1.200000e+08  6.552570e+06  2.705307e+07

# %%
# Retorna dimensão do DataFrame
df.shape
# Out:
# (32960, 9)

# %%
# Retorna quantidade de linhas validas por coluna
df.count()
# Out:
# Tipo          32960
# Bairro        32960
# Quartos       32960
# Vagas         32960
# Suites        32960
# Area          32960
# Valor         32943
# Condominio    28867
# IPTU          22723
# dtype: int64

# %%
# Lista os nomes das colunas
df.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# Lista os indexs
df.index
# Out:
# RangeIndex(start=0, stop=32960, step=1)

# %%
# Retorno semelhante ao head()
display(df)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
# Retorna toda a tabela do DataFrame
df_style = df.head(7)
df_style.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_53458_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Tipo</th>
#       <th class="col_heading level0 col1" >Bairro</th>
#       <th class="col_heading level0 col2" >Quartos</th>
#       <th class="col_heading level0 col3" >Vagas</th>
#       <th class="col_heading level0 col4" >Suites</th>
#       <th class="col_heading level0 col5" >Area</th>
#       <th class="col_heading level0 col6" >Valor</th>
#       <th class="col_heading level0 col7" >Condominio</th>
#       <th class="col_heading level0 col8" >IPTU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53458_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53458_row0_col0" class="data row0 col0" >Quitinete</td>
#       <td id="T_53458_row0_col1" class="data row0 col1" >Copacabana</td>
#       <td id="T_53458_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_53458_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_53458_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_53458_row0_col5" class="data row0 col5" >40</td>
#       <td id="T_53458_row0_col6" class="data row0 col6" >1700.000000</td>
#       <td id="T_53458_row0_col7" class="data row0 col7" >500.000000</td>
#       <td id="T_53458_row0_col8" class="data row0 col8" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_53458_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53458_row1_col0" class="data row1 col0" >Casa</td>
#       <td id="T_53458_row1_col1" class="data row1 col1" >Jardim Botânico</td>
#       <td id="T_53458_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_53458_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_53458_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_53458_row1_col5" class="data row1 col5" >100</td>
#       <td id="T_53458_row1_col6" class="data row1 col6" >7000.000000</td>
#       <td id="T_53458_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_53458_row1_col8" class="data row1 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_53458_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_53458_row2_col0" class="data row2 col0" >Conjunto Comercial/Sala</td>
#       <td id="T_53458_row2_col1" class="data row2 col1" >Barra da Tijuca</td>
#       <td id="T_53458_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_53458_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_53458_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_53458_row2_col5" class="data row2 col5" >150</td>
#       <td id="T_53458_row2_col6" class="data row2 col6" >5200.000000</td>
#       <td id="T_53458_row2_col7" class="data row2 col7" >4020.000000</td>
#       <td id="T_53458_row2_col8" class="data row2 col8" >1111.000000</td>
#     </tr>
#     <tr>
#       <th id="T_53458_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_53458_row3_col0" class="data row3 col0" >Apartamento</td>
#       <td id="T_53458_row3_col1" class="data row3 col1" >Centro</td>
#       <td id="T_53458_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_53458_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_53458_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_53458_row3_col5" class="data row3 col5" >15</td>
#       <td id="T_53458_row3_col6" class="data row3 col6" >800.000000</td>
#       <td id="T_53458_row3_col7" class="data row3 col7" >390.000000</td>
#       <td id="T_53458_row3_col8" class="data row3 col8" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_53458_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_53458_row4_col0" class="data row4 col0" >Apartamento</td>
#       <td id="T_53458_row4_col1" class="data row4 col1" >Higienópolis</td>
#       <td id="T_53458_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_53458_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_53458_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_53458_row4_col5" class="data row4 col5" >48</td>
#       <td id="T_53458_row4_col6" class="data row4 col6" >800.000000</td>
#       <td id="T_53458_row4_col7" class="data row4 col7" >230.000000</td>
#       <td id="T_53458_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_53458_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_53458_row5_col0" class="data row5 col0" >Apartamento</td>
#       <td id="T_53458_row5_col1" class="data row5 col1" >Vista Alegre</td>
#       <td id="T_53458_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_53458_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_53458_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_53458_row5_col5" class="data row5 col5" >70</td>
#       <td id="T_53458_row5_col6" class="data row5 col6" >1200.000000</td>
#       <td id="T_53458_row5_col7" class="data row5 col7" >nan</td>
#       <td id="T_53458_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_53458_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_53458_row6_col0" class="data row6 col0" >Apartamento</td>
#       <td id="T_53458_row6_col1" class="data row6 col1" >Cachambi</td>
#       <td id="T_53458_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_53458_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_53458_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_53458_row6_col5" class="data row6 col5" >50</td>
#       <td id="T_53458_row6_col6" class="data row6 col6" >1300.000000</td>
#       <td id="T_53458_row6_col7" class="data row6 col7" >301.000000</td>
#       <td id="T_53458_row6_col8" class="data row6 col8" >17.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Retorna os primeiros elementos / df.head(n) -> default: n = 5
df.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
df.head(2)
# Out:
#         Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Quitinete       Copacabana        1      0       0    40  1700.0
# 1       Casa  Jardim Botânico        2      0       1   100  7000.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN

# %%
# Retorna os últimos elementos / df.tail(n) -> default: n = 5
df.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
df.tail(2)
# Out:
#                           Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 32958              Apartamento  Leblon        2      0       0    70  3000.0
# 32959  Conjunto Comercial/Sala  Centro        0      0       0   250  6500.0
#
#        Condominio    IPTU
# 32958       760.0     NaN
# 32959      4206.0  1109.0

# %%
# Retorna elementos aleatórios / df.sample(n) -> default: n = 1
df.sample()
# Out:
#               Tipo   Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 20209  Apartamento  Ipanema        1      0       0    54  2300.0       444.0
#
#        IPTU
# 20209   NaN

# %%
df.sample(5)
# Out:
#                           Tipo         Bairro  Quartos  Vagas  Suites  Area  \
# 31167              Apartamento       Flamengo        4      0       0   430
# 9198               Apartamento         Leblon        4      3       4   220
# 17305       Casa de Condomínio       Cachambi        1      1       0    70
# 6014               Apartamento        Ipanema        2      2       1   170
# 29459  Galpão/Depósito/Armazém  Rocha Miranda        0      0       0   100
#
#          Valor  Condominio    IPTU
# 31167  13000.0      3100.0   835.0
# 9198   11900.0      3100.0  1000.0
# 17305   1000.0       150.0    13.0
# 6014    9500.0      1400.0   355.0
# 29459   6000.0         NaN     NaN

# %%
# Retorna coluna (Serie)
df["Tipo"]
# ou -> df.Tipo
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
# Identifica tipo de retorno
type(df['Bairro'])
# Out:
# pandas.core.series.Series

# %%
df[["Tipo","Bairro"]]
# Out:
#                           Tipo                Bairro
# 0                    Quitinete            Copacabana
# 1                         Casa       Jardim Botânico
# 2      Conjunto Comercial/Sala       Barra da Tijuca
# 3                  Apartamento                Centro
# 4                  Apartamento          Higienópolis
# ...                        ...                   ...
# 32955                Quitinete                Centro
# 32956              Apartamento           Jacarepaguá
# 32957              Apartamento  São Francisco Xavier
# 32958              Apartamento                Leblon
# 32959  Conjunto Comercial/Sala                Centro
#
# [32960 rows x 2 columns]

# %%
# Retorna um array de valores existentes em uma dada coluna
df["Tipo"].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# outra forma -> df.Tipo.unique()
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# Retorna uma Serie de quantidade por valor existente em uma dada coluna
df["Tipo"].value_counts()
# Out:
# Apartamento                    19532
# Conjunto Comercial/Sala         6815
# Loja/Salão                      1426
# Casa de Condomínio               996
# Casa                             967
# Quitinete                        836
# Galpão/Depósito/Armazém          623
# Flat                             476
# Prédio Inteiro                   301
# Casa Comercial                   265
# Casa de Vila                     249
# Loja Shopping/ Ct Comercial      247
# Box/Garagem                       82
# Terreno Padrão                    70
# Loft                              51
# Sítio                             10
# Loteamento/Condomínio              5
# Studio                             4
# Hotel                              2
# Chácara                            1
# Pousada/Chalé                      1
# Indústria                          1
# Name: Tipo, dtype: int64

# %%
# Retorna Serie com o maximo de cada Coluna
df.max()
# Out:
# Tipo          Terreno Padrão
# Bairro            Água Santa
# Quartos                  100
# Vagas                   1966
# Suites                    70
# Area                   90000
# Valor            120000000.0
# Condominio         6552570.0
# IPTU              27053070.0
# dtype: object

# %%
# Retorna Serie com o valor maximo de cada linha
df.max(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0        1700.0
# 1        7000.0
# 2        5200.0
# 3         800.0
# 4         800.0
#           ...
# 32955     800.0
# 32956    1800.0
# 32957    1400.0
# 32958    3000.0
# 32959    6500.0
# Length: 32960, dtype: float64

# %% [markdown]
# ## 2.2 - Selecionando linhas

# %% [markdown]
# ### 2.2.1 - Utilizando indices
#
# Indices de i a j-1 de linhas
#
#     df[ i : j ]

# %%
# Retorna os indices de 0 a (3-1)
df[0:3]
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0

# %% [markdown]
# ### 2.2.2 - Utilizando .loc
#
# **Observação:** Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.
#
#     df.loc[ lista_indices , lista_colunas ]

# %%
# DataFrame com index Categorico
df2.index
# Out:
# Index(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Apartamento', 'Apartamento', 'Apartamento', 'Casa de Condomínio',
#        'Casa de Condomínio', 'Conjunto Comercial/Sala',
#        ...
#        'Apartamento', 'Apartamento', 'Casa de Condomínio', 'Apartamento',
#        'Box/Garagem', 'Quitinete', 'Apartamento', 'Apartamento', 'Apartamento',
#        'Conjunto Comercial/Sala'],
#       dtype='object', name='Tipo', length=32960)

# %%
# Retorna conforme indice/index
df2.loc['Casa']
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area    Valor  \
# Tipo
# Casa           Jardim Botânico        2      0       1   100   7000.0
# Casa              Campo Grande        4      1       2   400  12000.0
# Casa                     Méier        2      0       0    51   1500.0
# Casa               São Conrado        4      2       4   730  28000.0
# Casa                  Maracanã        8      3       5   259   7000.0
# ...                        ...      ...    ...     ...   ...      ...
# Casa             Vila da Penha        2      1       0    80   1500.0
# Casa              Campo Grande        1      0       0    50    600.0
# Casa  Recreio dos Bandeirantes        4      2       2   352   6500.0
# Casa             Bento Ribeiro        2      1       0    60   1400.0
# Casa                    Centro        5      0       1   160   5000.0
#
#       Condominio     IPTU
# Tipo
# Casa         NaN      NaN
# Casa         NaN      NaN
# Casa        50.0      NaN
# Casa      2000.0  12000.0
# Casa         NaN      NaN
# ...          ...      ...
# Casa         NaN      NaN
# Casa         NaN      NaN
# Casa         NaN      NaN
# Casa         NaN      NaN
# Casa         NaN     80.0
#
# [967 rows x 8 columns]

# %%
# Retorna conforme indices/indexs -> [indices , colunas]
df2.loc[['Casa','Apartamento']]
# Out:
#                            Bairro  Quartos  Vagas  Suites  Area    Valor  \
# Tipo
# Casa              Jardim Botânico        2      0       1   100   7000.0
# Casa                 Campo Grande        4      1       2   400  12000.0
# Casa                        Méier        2      0       0    51   1500.0
# Casa                  São Conrado        4      2       4   730  28000.0
# Casa                     Maracanã        8      3       5   259   7000.0
# ...                           ...      ...    ...     ...   ...      ...
# Apartamento        Vila Valqueire        2      0       0    52   1000.0
# Apartamento                 Méier        2      0       0    70    900.0
# Apartamento           Jacarepaguá        3      1       2    78   1800.0
# Apartamento  São Francisco Xavier        2      1       0    48   1400.0
# Apartamento                Leblon        2      0       0    70   3000.0
#
#              Condominio     IPTU
# Tipo
# Casa                NaN      NaN
# Casa                NaN      NaN
# Casa               50.0      NaN
# Casa             2000.0  12000.0
# Casa                NaN      NaN
# ...                 ...      ...
# Apartamento       550.0      NaN
# Apartamento       490.0     48.0
# Apartamento       800.0     40.0
# Apartamento       509.0     37.0
# Apartamento       760.0      NaN
#
# [20499 rows x 8 columns]

# %%
# Retorna colunas conforme indices/indexs -> [indices , colunas]
df2.loc[['Casa','Apartamento'],['Vagas','Suites']]
# Out:
#              Vagas  Suites
# Tipo
# Casa             0       1
# Casa             1       2
# Casa             0       0
# Casa             2       4
# Casa             3       5
# ...            ...     ...
# Apartamento      0       0
# Apartamento      0       0
# Apartamento      1       2
# Apartamento      1       0
# Apartamento      0       0
#
# [20499 rows x 2 columns]

# %%
# Retorna tudo de duas colunas -> [indices , colunas]
df2.loc[:,['Vagas','Suites']]
# Out:
#                          Vagas  Suites
# Tipo
# Quitinete                    0       0
# Casa                         0       1
# Conjunto Comercial/Sala      4       0
# Apartamento                  0       0
# Apartamento                  0       0
# ...                        ...     ...
# Quitinete                    0       0
# Apartamento                  1       2
# Apartamento                  1       0
# Apartamento                  0       0
# Conjunto Comercial/Sala      0       0
#
# [32960 rows x 2 columns]

# %% [markdown]
# ### 2.2.3 - Utilizando .iloc
#
# **Observação:** Seleciona um grupo de linhas e colunas com base nos índices/index, ou seja, se baseia na posição das informações.
#
#
#     df.iloc[ lista_indices_linhas , lista_indices_colunas ]
#
# ou, de x a y semelhante uma lista:
#
#     df.iloc[ x : y ]

# %%
df.head(2)
# Out:
#         Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Quitinete       Copacabana        1      0       0    40  1700.0
# 1       Casa  Jardim Botânico        2      0       1   100  7000.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN

# %%
# Retorna Serie conforme indice(s) da linha 0 -> df 
df.iloc[0]
# Out:
# Tipo           Quitinete
# Bairro        Copacabana
# Quartos                1
# Vagas                  0
# Suites                 0
# Area                  40
# Valor             1700.0
# Condominio         500.0
# IPTU                60.0
# Name: 0, dtype: object

# %%
# Retorna Serie conforme indice(s) da linha 1 e 2 -> df2
df2.iloc[[1,2]]
# Out:
#                                   Bairro  Quartos  Vagas  Suites  Area  \
# Tipo
# Casa                     Jardim Botânico        2      0       1   100
# Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
#
#                           Valor  Condominio    IPTU
# Tipo
# Casa                     7000.0         NaN     NaN
# Conjunto Comercial/Sala  5200.0      4020.0  1111.0

# %%
# Retorna Serie conforme indice(s) da linhas de 0 e 4 -> df
df.iloc[0:4]
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0

# %%
# Retorna Serie conforme indice(s) da linhas de 0 e 4 e colunas 0,5,2, nesta ordem -> df
df.iloc[0:4,[0,5,2]]
# Out:
#                       Tipo  Area  Quartos
# 0                Quitinete    40        1
# 1                     Casa   100        2
# 2  Conjunto Comercial/Sala   150        0
# 3              Apartamento    15        1

# %%
# Retorna Serie conforme indice(s) da linhas 1,23,42 e colunas 0,5,2, nesta ordem -> df2
df2.iloc[[1,23,42],[0,5,2]]
# Out:
#                                            Bairro   Valor  Vagas
# Tipo
# Casa                              Jardim Botânico  7000.0      0
# Apartamento                                Olaria  1000.0      1
# Conjunto Comercial/Sala  Recreio dos Bandeirantes  1500.0      1

# %% [markdown]
# ### 2.2.4 - Utilizando condições em lista no DataFrame
#
#     df[ (condição) ]

# %%
# Retorna as linhas onde coluna igual a valor -> (df.coluna == valor)
df[ (df["Bairro"] == "Copacabana") ].head(5)
# Out:
#            Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0     Quitinete  Copacabana        1      0       0    40   1700.0
# 13  Apartamento  Copacabana        1      0       1    40   2000.0
# 14    Quitinete  Copacabana        1      0       0    27   1800.0
# 15  Apartamento  Copacabana        4      3       1   243  13000.0
# 33  Apartamento  Copacabana        3      1       2   378  10000.0
#
#     Condominio   IPTU
# 0        500.0   60.0
# 13       561.0   50.0
# 14       501.0    NaN
# 15      2000.0  803.0
# 33      2150.0  700.0

# %%
# ou Serie df[ (df.Bairro == "Copacabana") ]

# %%
# Retorna uma Serie boolean informando quais linhas atendem a condição
df.Bairro=='Copacabana'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Bairro, Length: 32960, dtype: bool

# %%
# Mais de uma condição: & -> and ; | -> or
# vazio pois (df['Bairro'] == True) não tem conrrespondência 
df[ (df.Bairro == 'Copacabana') & (df['Bairro'] == True) ]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ### 2.2.5 - Utilizando condições no método query
#
#     df.query( condição )

# %%
# Retorna um DataFrame conforme a query -> (coluna == valor)
df.query('Bairro == "Copacabana"')
# Out:
#               Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0        Quitinete  Copacabana        1      0       0    40   1700.0
# 13     Apartamento  Copacabana        1      0       1    40   2000.0
# 14       Quitinete  Copacabana        1      0       0    27   1800.0
# 15     Apartamento  Copacabana        4      3       1   243  13000.0
# 33     Apartamento  Copacabana        3      1       2   378  10000.0
# ...            ...         ...      ...    ...     ...   ...      ...
# 32900  Apartamento  Copacabana        1      0       0    60   2400.0
# 32916  Apartamento  Copacabana        2      0       0    67   2450.0
# 32936  Apartamento  Copacabana        2      0       1    70   4100.0
# 32938  Apartamento  Copacabana        1      0       0    50   1950.0
# 32945    Quitinete  Copacabana        1      0       0    22   1500.0
#
#        Condominio   IPTU
# 0           500.0   60.0
# 13          561.0   50.0
# 14          501.0    NaN
# 15         2000.0  803.0
# 33         2150.0  700.0
# ...           ...    ...
# 32900       530.0   78.0
# 32916       679.0   80.0
# 32936       700.0   90.0
# 32938       450.0   70.0
# 32945       286.0  200.0
#
# [3186 rows x 9 columns]

# %%
# Retorna um DataFrame conforme a query em mais de uma condição -> (coluna == valor)
df.query('Bairro == "Copacabana" and Area > 600')
# Out:
#                           Tipo      Bairro  Quartos  Vagas  Suites  Area  \
# 8447               Apartamento  Copacabana        4      3       4   700
# 9565            Prédio Inteiro  Copacabana        0      0       0  1400
# 9658               Apartamento  Copacabana        5      2       1   650
# 9687                     Hotel  Copacabana       24      0      24  1100
# 26088           Prédio Inteiro  Copacabana        0      0       0  1000
# 29094  Conjunto Comercial/Sala  Copacabana        0     10       0  1800
# 31308  Conjunto Comercial/Sala  Copacabana        0      5       0   900
#
#           Valor  Condominio    IPTU
# 8447    35000.0      1850.0   140.0
# 9565    32000.0         NaN  1700.0
# 9658    32000.0      5200.0  2000.0
# 9687    38000.0         NaN  7504.0
# 26088   22300.0         NaN     NaN
# 29094  198000.0     50400.0     NaN
# 31308   99000.0     25200.0     NaN

# %%
# Retorna onde valor da coluna atende a condição -> 3 < df['Quartos'] < 7
df[ df['Quartos'].between(3,7) ].shape
# Out:
# (10633, 9)

# %%
# Retorna onde valor da coluna atende a condição -> ~( 3 < df['Quartos'] < 7 )
# (~) NEGAÇÃO
df[ ~df['Quartos'].between(3,7) ].shape
# Out:
# (22327, 9)

# %%
# Retorna conforme a condição - Axis=1 = Linhas
# Valor máximo de cada linha é superior a 7000
df[ df.max(axis=1) > 7000 ]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 7           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 15                 Apartamento       Copacabana        4      3       1   243
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 22          Casa de Condomínio  Barra da Tijuca        4      3       2   466
# ...                        ...              ...      ...    ...     ...   ...
# 32928               Loja/Salão           Leblon        0      0       0    68
# 32937  Conjunto Comercial/Sala           Centro        0      0       0   150
# 32949              Apartamento          Ipanema        3      1       2   150
# 32952       Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 32954              Box/Garagem           Centro        0      0       0   755
#
#          Valor  Condominio    IPTU
# 7      22000.0         NaN     NaN
# 9      35000.0     19193.0  3030.0
# 15     13000.0      2000.0   803.0
# 16     28000.0         NaN  3563.0
# 22      7500.0      2695.0     NaN
# ...        ...         ...     ...
# 32928  25000.0         NaN  1113.0
# 32937  10000.0      2680.0   800.0
# 32949  15000.0      1400.0   600.0
# 32952  15000.0      1711.0  2332.0
# 32954  14000.0         NaN     NaN
#
# [7683 rows x 9 columns]

# %%
# Retorna onde tem valor 7 -> IS IN
df[ df['Quartos'].isin([7]) ].shape
# Out:
# (30, 9)

# %%
# Retorna a quantidade por tipo em Coluna (x)
df.groupby('Tipo').size()
# Out:
# Tipo
# Apartamento                    19532
# Box/Garagem                       82
# Casa                             967
# Casa Comercial                   265
# Casa de Condomínio               996
# Casa de Vila                     249
# Chácara                            1
# Conjunto Comercial/Sala         6815
# Flat                             476
# Galpão/Depósito/Armazém          623
# Hotel                              2
# Indústria                          1
# Loft                              51
# Loja Shopping/ Ct Comercial      247
# Loja/Salão                      1426
# Loteamento/Condomínio              5
# Pousada/Chalé                      1
# Prédio Inteiro                   301
# Quitinete                        836
# Studio                             4
# Sítio                             10
# Terreno Padrão                    70
# dtype: int64

# %% [markdown]
# ___
# # 3 - Manipulando Estruturas

# %% [markdown]
# ## 3.1 - Tratamento de dados

# %%
# Informações de DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Retorna Serie boolean com indices que a condição é Na
# ou -> df.Valor.isna()
rol = df["Valor"].isna()
rol
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Valor, Length: 32960, dtype: bool

# %%
rol.value_counts()
# Out:
# False    32943
# True        17
# Name: Valor, dtype: int64

# %%
# Retorna DataFrame onde condição é Na
df[ df['Valor'].isna() ]
# Out:
#                               Tipo                   Bairro  Quartos  Vagas  \
# 76                     Apartamento          Barra da Tijuca        2      1
# 2186                   Apartamento                     Leme        2      0
# 2456                          Casa             Campo Grande        3      4
# 2646                    Loja/Salão          Barra da Tijuca        0      2
# 2941                   Apartamento                 Botafogo        2      0
# 2973                   Apartamento               Copacabana        2      0
# 6598                    Loja/Salão                  Andaraí        0      0
# 7302                          Casa             Campo Grande        3      2
# 12683                  Apartamento                     Leme        2      0
# 13229                  Apartamento                   Glória        3      0
# 13525                  Apartamento                    Gávea        3      1
# 13579      Conjunto Comercial/Sala                 Botafogo        0      3
# 20948      Conjunto Comercial/Sala  Freguesia (Jacarepaguá)        0      1
# 21822  Loja Shopping/ Ct Comercial          Barra da Tijuca        0      2
# 23056      Conjunto Comercial/Sala                 Botafogo        0      0
# 24805      Conjunto Comercial/Sala                 Botafogo        0      0
# 29166      Conjunto Comercial/Sala                 Botafogo        0      1
#
#        Suites  Area  Valor  Condominio    IPTU
# 76          1    70    NaN       970.0    68.0
# 2186        0    75    NaN       878.0     NaN
# 2456        3   363    NaN         NaN     NaN
# 2646        0    80    NaN         NaN     NaN
# 2941        0    95    NaN      1010.0   170.0
# 2973        0    72    NaN       850.0     NaN
# 6598        0   326    NaN         NaN  1140.0
# 7302        1   100    NaN         NaN     NaN
# 12683       1    75    NaN       878.0     NaN
# 13229       1   135    NaN       910.0   228.0
# 13525       1   105    NaN       880.0   221.0
# 13579       0   200    NaN        10.0     NaN
# 20948       0    24    NaN       500.0    74.0
# 21822       0    77    NaN      3600.0  1390.0
# 23056       0   900    NaN        10.0     NaN
# 24805       0   500    NaN        10.0     NaN
# 29166       0    50    NaN        10.0     NaN

# %%
# Altera todos os valor NaN para 0
rol2 = df.fillna(0)
rol2[ rol2['Valor'].isna() ]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ___
# # 4 - Data Visualização
